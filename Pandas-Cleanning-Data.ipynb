# %%
import pandas as pd

# %%
df = pd.read_excel (r"C:\Users\Padka\OneDrive\Desktop\Learning Python\Customer Call List.xlsx")
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
# Delete duplicate rows

df.drop_duplicates(inplace=True)
df

# %%
# Delete a useless column

df.drop(columns = "Not_Useful_Column", inplace=True)
df

# %%
# Strip unwanted characters from the "Last_Name" column

# df["Last_Name"] = df["Last_Name"].str.lstrip("...")
# df["Last_Name"] = df["Last_Name"].str.lstrip("/")
# df["Last_Name"] = df["Last_Name"].str.rstrip("_")
df["Last_Name"] = df["Last_Name"].str.strip("123._/")
df

# %%
# Strip unwanted characters from the "Phone_Number" column and format it as XXX-XXX-XXXX

# df["Phone_Number"] = df["Phone_Number"].str.replace('[^a-zA-Z0-9]','',regex=True)
# df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x))
# df["Phone_Number"] = df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])
df["Phone_Number"] = df["Phone_Number"].str.replace('nan--','')
df["Phone_Number"] = df["Phone_Number"].str.replace('Na--','')
df

# %%
# Split the "Address" column into three new columns: "Street Address", "State", and "Zip_code"

df[["Street Address","State","Zip_code"]] = df["Address"].str.split(',', n=2, expand=True)
df

# %%
# Replace "Yes" with "Y" and "No" with "N" in the "Paying Customer" column

df["Paying Customer"] = df["Paying Customer"].str.replace('Yes','Y')
df["Paying Customer"] = df["Paying Customer"].str.replace('No','N')
df

# %%
# Replace "Yes" with "Y" and "No" with "N" in the "Do_Not_Contact" column

df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('Yes','Y')
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('No','N')
df["Do_Not_Contact"]

# %%
# Replace "N/a" and "NaN" with an empty string in the entire DataFrame

# df = df.replace('N/a','')
# df = df.replace('NaN','')
df = df.fillna('')
df

# %%
# Delete rows where the "Do_Not_Contact" column has a value of "Y"

for x in df.index:
    if df.loc[x, "Do_Not_Contact"] == 'Y':
        df.drop(x, inplace = True)
df

# %%
# Delete rows where the "Phone_Number" column has an empty string as a value

for x in df.index:
    if df.loc[x, "Phone_Number"] == '':
        df.drop(x, inplace = True)
df

# df.dropna(subset = "Phone_Number",inplace = True)

# %%
# Delete the "Address" column since we have already split it into three new columns

df = df.drop(columns= "Address")

# %%
# Reset the index of the DataFrame after deleting rows

df = df.reset_index(drop=True)
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number Paying Customer  \
# 0        1001      Frodo   Baggins  123-545-5421               Y
# 1        1005        Jon      Snow  876-678-3469               Y
# 2        1008   Sherlock    Holmes  876-678-3469               N
# 3        1010      Peter    Parker  123-545-5421               Y
# 4        1013        Don    Draper  123-543-2345               Y
#
#   Do_Not_Contact    Street Address      State Zip_code
# 0              N    123 Shire Lane      Shire
# 1              N  123 Dragons Road
# 2              N     98 Clue Drive
# 3              N  25th Main Street   New York
# 4              N  2039 Main Street
